# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm
import sys
# !{sys.executable} -m pip install pyarrow
# !{sys.executable} -m pip install yfinance
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 21.2.4; however, version 25.1.1 is available.
# You should consider upgrading via the '/Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 118 kB 922 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 425 kB 5.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.0 MB 15.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 173 kB 24.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.0 MB 21.5 MB/s eta 0:00:01
#   WARNING: Value for prefixed-purelib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/85/zy7z6hzx3cq3nw4s6pzqgw0w0000gn/T/pip-build-env-dd4m88r_/normal/lib/python3.9/site-packages
# ...

# %%
df=pd.read_parquet("train_data.parquet")

# %%
df['timestamp']=pd.to_datetime(df['timestamp'])
df.tail()
# Out:
#                  timestamp  underlying      expiry  call_iv_23500  \
# 178335 2025-05-07 09:29:56     24358.8  2025-05-08       0.421949
# 178336 2025-05-07 09:29:57     24359.6  2025-05-08       0.418388
# 178337 2025-05-07 09:29:58     24358.5  2025-05-08       0.422143
# 178338 2025-05-07 09:29:59     24358.5  2025-05-08       0.421115
# 178339 2025-05-07 09:30:00     24357.8  2025-05-08       0.421030
#
#         call_iv_23600  call_iv_23700  call_iv_23800  call_iv_23900  \
# 178335       0.393037       0.362155       0.330184       0.294492
# 178336       0.390950       0.361965       0.329852       0.294419
# 178337       0.394667       0.363130       0.329679       0.294183
# 178338       0.394881       0.363162       0.329524       0.294258
# 178339       0.394341       0.362419       0.329137       0.294291
#
#         call_iv_24000  call_iv_24100  ...       X32       X33            X34  \
# 178335       0.256301       0.218157  ... -0.011905  0.000325 -354025.390625
# ...

# %%
import yfinance as yf

# Get NIFTY index data (symbol: ^NSEI or ^NIFTY for Yahoo Finance)
nifty = yf.download("^NSEI", start="2025-03-12", end="2025-03-13", interval="1d")

# Print closing price on 12-Jun-2025
print("NIFTY Spot on Expiry:", nifty['Close'].iloc[0])
# Out:
# /var/folders/85/zy7z6hzx3cq3nw4s6pzqgw0w0000gn/T/ipykernel_66429/962445205.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   nifty = yf.download("^NSEI", start="2025-03-12", end="2025-03-13", interval="1d")
# [*********************100%***********************]  1 of 1 completed
# NIFTY Spot on Expiry: Ticker
# ^NSEI    22470.5
# Name: 2025-03-12 00:00:00, dtype: float64

# %%
nifty = yf.Ticker("^NSEI")

# %%
spot_data = nifty.history(period="1d")
spot_data
# Out:
#                                    Open          High           Low  \
# Date
# 2025-06-10 00:00:00+05:30  25196.050781  25199.300781  25055.449219
#
#                                   Close  Volume  Dividends  Stock Splits
# Date
# 2025-06-10 00:00:00+05:30  25143.449219       0        0.0           0.0

# %%
hist = nifty.history(start="2024-06-01", end="2024-06-30")
hist
# Out:
#                                    Open          High           Low  \
# Date
# 2024-06-03 00:00:00+05:30  23337.900391  23338.699219  23062.300781
# 2024-06-04 00:00:00+05:30  23179.500000  23179.500000  21281.449219
# 2024-06-05 00:00:00+05:30  22128.349609  22670.400391  21791.949219
# 2024-06-06 00:00:00+05:30  22798.599609  22910.150391  22642.599609
# 2024-06-07 00:00:00+05:30  22821.849609  23320.199219  22789.050781
# 2024-06-10 00:00:00+05:30  23319.150391  23411.900391  23227.150391
# 2024-06-11 00:00:00+05:30  23283.750000  23389.449219  23206.650391
# 2024-06-12 00:00:00+05:30  23344.449219  23441.949219  23295.949219
# 2024-06-13 00:00:00+05:30  23480.949219  23481.050781  23353.900391
# 2024-06-14 00:00:00+05:30  23464.949219  23490.400391  23334.250000
# 2024-06-18 00:00:00+05:30  23570.800781  23579.050781  23499.699219
# 2024-06-19 00:00:00+05:30  23629.849609  23664.000000  23412.900391
# 2024-06-20 00:00:00+05:30  23586.150391  23624.000000  23442.599609
# ...

# %%
stock = yf.Ticker("RELIANCE.NS")
opt = stock.option_chain("2024-06-21")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 2
#       1 stock = yf.Ticker("RELIANCE.NS")
# ----> 2 opt = stock.option_chain("2024-06-21")
#
# File ~/Library/Python/3.9/lib/python/site-packages/yfinance/ticker.py:94, in Ticker.option_chain(self, date, tz)
#      92     self._download_options()
#      93 if date not in self._expirations:
# ---> 94     raise ValueError(
#      95         f"Expiration `{date}` cannot be found. "
#      96         f"Available expirations are: [{', '.join(self._expirations)}]")
#      97 date = self._expirations[date]
#      98 options = self._download_options(date)
#
# ValueError: Expiration `2024-06-21` cannot be found. Available expirations are: []
